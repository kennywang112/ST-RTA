# %% [markdown]
# 分析改用特定道路組合下為有設施的機率

# %%
import os
import pandas as pd
import bnlearn as bn
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['Arial Unicode Ms']

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
analyze_path = os.path.join(parent_dir, "utils")

os.chdir(analyze_path)

# %%
# This is from TDAv2
combined_data = pd.read_csv('../ComputedData/ForModel/combined_data_with_hotspot.csv')
combined_data.shape

# %%
select_group = [
    # 號誌
    '號誌-號誌種類名稱', '號誌-號誌動作名稱',

    # 車道劃分
    '車道劃分設施-分道設施-快車道或一般車道間名稱',
    '車道劃分設施-分道設施-快慢車道間名稱', '車道劃分設施-分道設施-路面邊線名稱',

    # 大類別
    '事故類型及型態子類別名稱', '車道劃分設施-分向設施子類別名稱',
    '道路型態子類別名稱',

    # 其他
    '速限-第1當事者',
    '道路類別-第1當事者-名稱',

    # 設施
    'youbike_100m_count',
    
    # 駕駛、行人行為
    '肇因研判子類別名稱-主要',

    'COUNTYNAME'
    ]

data = combined_data[select_group].copy()
data['facility'] = data[['youbike_100m_count']].apply(lambda row: '1' if (row > 0).any() else '0', axis=1)
data.drop(columns=['youbike_100m_count'], inplace=True)

max_speed = data['速限-第1當事者'].max()
bins = range(0, int(max_speed) + 11, 10)

data['速限-第1當事者'] = pd.cut(
    data['速限-第1當事者'],
    bins=bins,
    right=False, 
    include_lowest=True,
    labels=[f"{i}-{i+9}" for i in bins[:-1]]
)

# %%
parent = [
    '號誌-號誌種類名稱', '號誌-號誌動作名稱','車道劃分設施-分道設施-快車道或一般車道間名稱', '車道劃分設施-分道設施-快慢車道間名稱',
    '車道劃分設施-分道設施-路面邊線名稱', '車道劃分設施-分向設施子類別名稱', '道路型態子類別名稱',
    '速限-第1當事者', '道路類別-第1當事者-名稱', 'facility', 'COUNTYNAME'
    ]
cause = ['肇因研判子類別名稱-主要']
result = ['事故類型及型態子類別名稱']

white_list = [
    ('速限-第1當事者', '肇因研判子類別名稱-主要'),
    ('道路類別-第1當事者-名稱', '肇因研判子類別名稱-主要'),
    ('道路型態子類別名稱', '肇因研判子類別名稱-主要'),
    ('facility', '肇因研判子類別名稱-主要'),
    ('號誌-號誌種類名稱', '肇因研判子類別名稱-主要'),
]

black_list = []
# cause -> parent
black_list += [(c, p) for c in cause for p in parent]
# result -> parent/cause
black_list += [(r, x) for r in result for x in (parent + cause + result)]

# %%
def get_model(dt):
    # 學哪些變數之間有邊，結果是一個DAG
    model = bn.structure_learning.fit(dt, methodtype='hc', scoretype='bic', bw_list_method='edges',
                                    # 肇因對於事故類型一定是上游。ex. 不會因為撞路樹而造成患病，而是因為患病才造成撞路樹
                                    black_list=black_list, white_list=white_list,
                                    fixed_edges=white_list, max_indegree=None)
    # 計算每個節點的 條件機率表 (CPT, Conditional Probability Table)
    model_param = bn.parameter_learning.fit(model, dt, scoretype='bdeu', methodtype='bayes')
    # 計算邊緣強度，如果p小於顯著就是有相關
    model_independence = bn.independence_test(model_param, dt, test='chi_square', prune=True)

    return model, model_param, model_independence

model_all, model_param_all, model_independence_all = get_model(data)
# Out:
# [bnlearn] >Warning: Computing DAG with 13 nodes can take a very long time!
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Filter edges based on black_list/white_list
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of 號誌-號誌種類名稱:
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(無號誌)              | 0.587743  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(行車管制號誌)           | 0.261864  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(行車管制號誌(附設行人專用號誌)) | 0.099486  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(閃光號誌)             | 0.0509074 |
# +-----------------------------+-----------+
# [bnlearn] >CPD of 肇因研判子類別名稱-主要:
# +-----+----------------------+
# | ... | facility(1)          |
# +-----+----------------------+
# | ... | 號誌-號誌種類名稱(閃光號誌)      |
# +-----+----------------------+
# | ... | 速限-第1當事者(90-99)      |
# +-----+----------------------+
# | ... | 道路型態子類別名稱(高架道路)      |
# +-----+----------------------+
# | ... | 道路類別-第1當事者-名稱(鄉道)    |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# [bnlearn] >CPD of 道路型態子類別名稱:
# +--------------------+-------------+
# | 道路型態子類別名稱(三岔路)     | 0.222056    |
# +--------------------+-------------+
# | 道路型態子類別名稱(休息站或服務區) | 0.000269794 |
# +--------------------+-------------+
# | 道路型態子類別名稱(其他)      | 0.00722447  |
# +--------------------+-------------+
# | 道路型態子類別名稱(四岔路)     | 0.335252    |
# +--------------------+-------------+
# | 道路型態子類別名稱(圓環)      | 0.00209051  |
# +--------------------+-------------+
# | 道路型態子類別名稱(地下道)     | 0.000986087 |
# +--------------------+-------------+
# | 道路型態子類別名稱(坡路)      | 0.0031823   |
# +--------------------+-------------+
# | 道路型態子類別名稱(多岔路)     | 0.0412153   |
# +--------------------+-------------+
# | 道路型態子類別名稱(廣場)      | 0.000266638 |
# +--------------------+-------------+
# | 道路型態子類別名稱(彎曲路及附近)  | 0.0275079   |
# +--------------------+-------------+
# | 道路型態子類別名稱(有遮斷器)    | 0.000228772 |
# +--------------------+-------------+
# | 道路型態子類別名稱(橋樑)      | 0.00487995  |
# +--------------------+-------------+
# | 道路型態子類別名稱(涵洞)      | 0.000604274 |
# +--------------------+-------------+
# | 道路型態子類別名稱(直路)      | 0.351566    |
# +--------------------+-------------+
# | 道路型態子類別名稱(隧道)      | 0.000708405 |
# +--------------------+-------------+
# | 道路型態子類別名稱(高架道路)    | 0.00196113  |
# +--------------------+-------------+
# [bnlearn] >CPD of 速限-第1當事者:
# +-------------------+------------+
# | 速限-第1當事者(0-9)     | 0.0123421  |
# +-------------------+------------+
# | 速限-第1當事者(10-19)   | 0.00258855 |
# +-------------------+------------+
# | 速限-第1當事者(100-109) | 0.00352257 |
# +-------------------+------------+
# | 速限-第1當事者(110-119) | 0.00379394 |
# +-------------------+------------+
# | 速限-第1當事者(20-29)   | 0.00402744 |
# +-------------------+------------+
# | 速限-第1當事者(30-39)   | 0.144112   |
# +-------------------+------------+
# | 速限-第1當事者(40-49)   | 0.13438    |
# +-------------------+------------+
# | 速限-第1當事者(50-59)   | 0.640052   |
# +-------------------+------------+
# | 速限-第1當事者(60-69)   | 0.0394477  |
# +-------------------+------------+
# | 速限-第1當事者(70-79)   | 0.0118309  |
# +-------------------+------------+
# | 速限-第1當事者(80-89)   | 0.00155039 |
# +-------------------+------------+
# | 速限-第1當事者(90-99)   | 0.00235188 |
# +-------------------+------------+
# [bnlearn] >CPD of 道路類別-第1當事者-名稱:
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(其他)     | 0.0330414  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(國道)     | 0.00966559 |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(專用道路)   | 0.0029097  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(市區道路)   | 0.790486   |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(快速(公)道) | 0.0012373  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(村里道路)   | 0.102594   |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(省道)     | 0.0197915  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(縣道)     | 0.0242123  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(鄉道)     | 0.0160617  |
# +-----------------------+------------+
# [bnlearn] >CPD of facility:
# +-------------+----------+
# | facility(0) | 0.806052 |
# +-------------+----------+
# | facility(1) | 0.193948 |
# +-------------+----------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Compute edge strength with [chi_square]

# %%
from utils_behaviour import draw_bn_plotly
draw_bn_plotly(model_independence_all, layout_algo='spring', en=False, width=600, height=400, seed=42, iter=30)

# %%
from utils_behaviour import cpd_add_n, filter_cpd_for_hotspot, get_outlier
from config import category_value_map, feature_name_map
parent = ['速限-第1當事者', '道路類別-第1當事者-名稱', '道路型態子類別名稱', 'facility', '號誌-號誌種類名稱']
child = '肇因研判子類別名稱-主要'
evidence_v = list(data['肇因研判子類別名稱-主要'].value_counts().head(5).index)

# %%
CPDs = bn.print_CPD(model_param_all)
dfprob_cause = CPDs[child]
filtered = cpd_add_n(parent, child, dfprob_cause, data, threshold=0)
# Out:
# [bnlearn] >[CPD] >[Node 號誌-號誌種類名稱]:
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(無號誌)              | 0.587743  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(行車管制號誌)           | 0.261864  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(行車管制號誌(附設行人專用號誌)) | 0.099486  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(閃光號誌)             | 0.0509074 |
# +-----------------------------+-----------+
# [bnlearn] >[CPD] >[Node 肇因研判子類別名稱-主要]:
# +-----+----------------------+
# | ... | facility(1)          |
# +-----+----------------------+
# | ... | 號誌-號誌種類名稱(閃光號誌)      |
# +-----+----------------------+
# | ... | 速限-第1當事者(90-99)      |
# +-----+----------------------+
# | ... | 道路型態子類別名稱(高架道路)      |
# +-----+----------------------+
# | ... | 道路類別-第1當事者-名稱(鄉道)    |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# | ... | 0.008849557522123883 |
# +-----+----------------------+
# [bnlearn] >[CPD] >[Node 道路型態子類別名稱]:
# +--------------------+-------------+
# | 道路型態子類別名稱(三岔路)     | 0.222056    |
# +--------------------+-------------+
# | 道路型態子類別名稱(休息站或服務區) | 0.000269794 |
# +--------------------+-------------+
# | 道路型態子類別名稱(其他)      | 0.00722447  |
# +--------------------+-------------+
# | 道路型態子類別名稱(四岔路)     | 0.335252    |
# +--------------------+-------------+
# | 道路型態子類別名稱(圓環)      | 0.00209051  |
# +--------------------+-------------+
# | 道路型態子類別名稱(地下道)     | 0.000986087 |
# +--------------------+-------------+
# | 道路型態子類別名稱(坡路)      | 0.0031823   |
# +--------------------+-------------+
# | 道路型態子類別名稱(多岔路)     | 0.0412153   |
# +--------------------+-------------+
# | 道路型態子類別名稱(廣場)      | 0.000266638 |
# +--------------------+-------------+
# | 道路型態子類別名稱(彎曲路及附近)  | 0.0275079   |
# +--------------------+-------------+
# | 道路型態子類別名稱(有遮斷器)    | 0.000228772 |
# +--------------------+-------------+
# | 道路型態子類別名稱(橋樑)      | 0.00487995  |
# +--------------------+-------------+
# | 道路型態子類別名稱(涵洞)      | 0.000604274 |
# +--------------------+-------------+
# | 道路型態子類別名稱(直路)      | 0.351566    |
# +--------------------+-------------+
# | 道路型態子類別名稱(隧道)      | 0.000708405 |
# +--------------------+-------------+
# | 道路型態子類別名稱(高架道路)    | 0.00196113  |
# +--------------------+-------------+
# [bnlearn] >[CPD] >[Node 速限-第1當事者]:
# +-------------------+------------+
# | 速限-第1當事者(0-9)     | 0.0123421  |
# +-------------------+------------+
# | 速限-第1當事者(10-19)   | 0.00258855 |
# +-------------------+------------+
# | 速限-第1當事者(100-109) | 0.00352257 |
# +-------------------+------------+
# | 速限-第1當事者(110-119) | 0.00379394 |
# +-------------------+------------+
# | 速限-第1當事者(20-29)   | 0.00402744 |
# +-------------------+------------+
# | 速限-第1當事者(30-39)   | 0.144112   |
# +-------------------+------------+
# | 速限-第1當事者(40-49)   | 0.13438    |
# +-------------------+------------+
# | 速限-第1當事者(50-59)   | 0.640052   |
# +-------------------+------------+
# | 速限-第1當事者(60-69)   | 0.0394477  |
# +-------------------+------------+
# | 速限-第1當事者(70-79)   | 0.0118309  |
# +-------------------+------------+
# | 速限-第1當事者(80-89)   | 0.00155039 |
# +-------------------+------------+
# | 速限-第1當事者(90-99)   | 0.00235188 |
# +-------------------+------------+
# [bnlearn] >[CPD] >[Node 道路類別-第1當事者-名稱]:
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(其他)     | 0.0330414  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(國道)     | 0.00966559 |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(專用道路)   | 0.0029097  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(市區道路)   | 0.790486   |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(快速(公)道) | 0.0012373  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(村里道路)   | 0.102594   |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(省道)     | 0.0197915  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(縣道)     | 0.0242123  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(鄉道)     | 0.0160617  |
# +-----------------------+------------+
# [bnlearn] >[CPD] >[Node facility]:
# +-------------+----------+
# | facility(0) | 0.806052 |
# +-------------+----------+
# | facility(1) | 0.193948 |
# +-------------+----------+
# [bnlearn] >Independencies:
# (速限-第1當事者 ⟂ facility, 道路型態子類別名稱, 號誌-號誌種類名稱, 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ facility, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | 道路型態子類別名稱)
# (速限-第1當事者 ⟂ facility, 道路型態子類別名稱, 號誌-號誌種類名稱 | 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ facility, 道路型態子類別名稱, 道路類別-第1當事者-名稱 | 號誌-號誌種類名稱)
# (速限-第1當事者 ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱, 道路類別-第1當事者-名稱 | facility)
# (速限-第1當事者 ⟂ facility, 號誌-號誌種類名稱 | 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ facility, 道路類別-第1當事者-名稱 | 道路型態子類別名稱, 號誌-號誌種類名稱)
# (速限-第1當事者 ⟂ 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | facility, 道路型態子類別名稱)
# (速限-第1當事者 ⟂ facility, 道路型態子類別名稱 | 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (速限-第1當事者 ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱 | facility, 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ 道路型態子類別名稱, 道路類別-第1當事者-名稱 | facility, 號誌-號誌種類名稱)
# (速限-第1當事者 ⟂ facility | 道路型態子類別名稱, 號誌-號誌種類名稱, 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ 號誌-號誌種類名稱 | facility, 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ 道路類別-第1當事者-名稱 | facility, 道路型態子類別名稱, 號誌-號誌種類名稱)
# (速限-第1當事者 ⟂ 道路型態子類別名稱 | facility, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ facility, 速限-第1當事者, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ facility, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | 速限-第1當事者)
# (道路型態子類別名稱 ⟂ facility, 速限-第1當事者, 號誌-號誌種類名稱 | 道路類別-第1當事者-名稱)
# (道路型態子類別名稱 ⟂ facility, 速限-第1當事者, 道路類別-第1當事者-名稱 | 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | facility)
# (道路型態子類別名稱 ⟂ facility, 號誌-號誌種類名稱 | 速限-第1當事者, 道路類別-第1當事者-名稱)
# (道路型態子類別名稱 ⟂ facility, 道路類別-第1當事者-名稱 | 速限-第1當事者, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | facility, 速限-第1當事者)
# (道路型態子類別名稱 ⟂ facility, 速限-第1當事者 | 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 速限-第1當事者, 號誌-號誌種類名稱 | facility, 道路類別-第1當事者-名稱)
# (道路型態子類別名稱 ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱 | facility, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ facility | 速限-第1當事者, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 號誌-號誌種類名稱 | facility, 速限-第1當事者, 道路類別-第1當事者-名稱)
# (道路型態子類別名稱 ⟂ 道路類別-第1當事者-名稱 | facility, 速限-第1當事者, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 速限-第1當事者 | facility, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ facility, 速限-第1當事者, 道路型態子類別名稱, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ facility, 道路型態子類別名稱, 號誌-號誌種類名稱 | 速限-第1當事者)
# (道路類別-第1當事者-名稱 ⟂ facility, 速限-第1當事者, 號誌-號誌種類名稱 | 道路型態子類別名稱)
# (道路類別-第1當事者-名稱 ⟂ facility, 速限-第1當事者, 道路型態子類別名稱 | 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱, 號誌-號誌種類名稱 | facility)
# (道路類別-第1當事者-名稱 ⟂ facility, 號誌-號誌種類名稱 | 速限-第1當事者, 道路型態子類別名稱)
# (道路類別-第1當事者-名稱 ⟂ facility, 道路型態子類別名稱 | 速限-第1當事者, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱 | facility, 速限-第1當事者)
# (道路類別-第1當事者-名稱 ⟂ facility, 速限-第1當事者 | 道路型態子類別名稱, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者, 號誌-號誌種類名稱 | facility, 道路型態子類別名稱)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱 | facility, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ facility | 速限-第1當事者, 道路型態子類別名稱, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 號誌-號誌種類名稱 | facility, 速限-第1當事者, 道路型態子類別名稱)
# (道路類別-第1當事者-名稱 ⟂ 道路型態子類別名稱 | facility, 速限-第1當事者, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者 | facility, 道路型態子類別名稱, 號誌-號誌種類名稱)
# (號誌-號誌種類名稱 ⟂ facility, 速限-第1當事者, 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ facility, 道路型態子類別名稱, 道路類別-第1當事者-名稱 | 速限-第1當事者)
# (號誌-號誌種類名稱 ⟂ facility, 速限-第1當事者, 道路類別-第1當事者-名稱 | 道路型態子類別名稱)
# (號誌-號誌種類名稱 ⟂ facility, 速限-第1當事者, 道路型態子類別名稱 | 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱, 道路類別-第1當事者-名稱 | facility)
# (號誌-號誌種類名稱 ⟂ facility, 道路類別-第1當事者-名稱 | 速限-第1當事者, 道路型態子類別名稱)
# (號誌-號誌種類名稱 ⟂ facility, 道路型態子類別名稱 | 速限-第1當事者, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 道路型態子類別名稱, 道路類別-第1當事者-名稱 | facility, 速限-第1當事者)
# (號誌-號誌種類名稱 ⟂ facility, 速限-第1當事者 | 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱 | facility, 道路型態子類別名稱)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱 | facility, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ facility | 速限-第1當事者, 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 道路類別-第1當事者-名稱 | facility, 速限-第1當事者, 道路型態子類別名稱)
# (號誌-號誌種類名稱 ⟂ 道路型態子類別名稱 | facility, 速限-第1當事者, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者 | facility, 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (facility ⟂ 速限-第1當事者, 道路型態子類別名稱, 號誌-號誌種類名稱, 道路類別-第1當事者-名稱)
# (facility ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱, 道路類別-第1當事者-名稱 | 速限-第1當事者)
# (facility ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | 道路型態子類別名稱)
# (facility ⟂ 速限-第1當事者, 道路型態子類別名稱, 號誌-號誌種類名稱 | 道路類別-第1當事者-名稱)
# (facility ⟂ 速限-第1當事者, 道路型態子類別名稱, 道路類別-第1當事者-名稱 | 號誌-號誌種類名稱)
# (facility ⟂ 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | 速限-第1當事者, 道路型態子類別名稱)
# (facility ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱 | 速限-第1當事者, 道路類別-第1當事者-名稱)
# (facility ⟂ 道路型態子類別名稱, 道路類別-第1當事者-名稱 | 速限-第1當事者, 號誌-號誌種類名稱)
# (facility ⟂ 速限-第1當事者, 號誌-號誌種類名稱 | 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (facility ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱 | 道路型態子類別名稱, 號誌-號誌種類名稱)
# (facility ⟂ 速限-第1當事者, 道路型態子類別名稱 | 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (facility ⟂ 號誌-號誌種類名稱 | 速限-第1當事者, 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (facility ⟂ 道路類別-第1當事者-名稱 | 速限-第1當事者, 道路型態子類別名稱, 號誌-號誌種類名稱)
# (facility ⟂ 道路型態子類別名稱 | 速限-第1當事者, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (facility ⟂ 速限-第1當事者 | 道路型態子類別名稱, 號誌-號誌種類名稱, 道路類別-第1當事者-名稱)
# [bnlearn] >Nodes: ['號誌-號誌種類名稱', '肇因研判子類別名稱-主要', '道路型態子類別名稱', '速限-第1當事者', '道路類別-第1當事者-名稱', 'facility']
# [bnlearn] >Edges: [('號誌-號誌種類名稱', '肇因研判子類別名稱-主要'), ('道路型態子類別名稱', '肇因研判子類別名稱-主要'), ('速限-第1當事者', '肇因研判子類別名稱-主要'), ('道路類別-第1當事者-名稱', '肇因研判子類別名稱-主要'), ('facility', '肇因研判子類別名稱-主要')]

# %%
filtered_n = filtered[filtered['n'] > 0]
filtered_n.sort_values(by=['號誌-號誌種類名稱', '速限-第1當事者', '道路型態子類別名稱', 'facility', 'p'], ascending=False, inplace=True)

filtered_n['total_n'] = (
    filtered_n
    .groupby(parent)['n']
    .transform('sum')
)

filtered_n.sort_values(by=['total_n', 'p'], ascending=False, inplace=True)

# %%
check_sum = (filtered_n.groupby(parent)['p'].sum())
check_sum

# %%
filtered_n = filtered_n[['道路類別-第1當事者-名稱', '號誌-號誌種類名稱', '速限-第1當事者', '道路型態子類別名稱', '肇因研判子類別名稱-主要', 'facility', 'p', 'n', 'total_n']]
filtered_n.sort_values(
    by=['號誌-號誌種類名稱', '速限-第1當事者', '道路型態子類別名稱', '肇因研判子類別名稱-主要', '道路類別-第1當事者-名稱', 'facility'], 
    ascending=False, inplace=False)
filtered_n
# Out:
#         道路類別-第1當事者-名稱 號誌-號誌種類名稱 速限-第1當事者 道路型態子類別名稱    肇因研判子類別名稱-主要 facility  \
# 623208           市區道路       無號誌    50-59        直路       未保持行車安全距離        0
# 111720           市區道路       無號誌    50-59        直路        其他不當駕車行為        0
# 402024           市區道路       無號誌    50-59        直路  恍神、緊張、心不在焉分心駕駛        0
# 996456           市區道路       無號誌    50-59        直路        起步時未注意安全        0
# 637032           市區道路       無號誌    50-59        直路       未保持行車安全間隔        0
# ...               ...       ...      ...       ...             ...      ...
# 221209             縣道       無號誌      0-9        其他         右轉彎未依規定        0
# 1230362            鄉道       無號誌      0-9        其他     違反其他標誌(線)禁制        0
# 877831             縣道       無號誌      0-9       三岔路     穿越道路未注意左右來車        1
# 1499909          村里道路       無號誌      0-9       三岔路       開啟或關閉車門不當        1
# 110594           專用道路       無號誌      0-9       三岔路        其他不當駕車行為        0
#
#               p     n  total_n
# 623208   0.1401  5473    39056
# 111720   0.1346  5258    39056
# 402024   0.1076  4202    39056
# 996456   0.0763  2981    39056
# 637032   0.0541  2114    39056
# ...         ...   ...      ...
# 221209   0.9331     1        1
# 1230362  0.9331     1        1
# 877831   0.9331     1        1
# 1499909  0.9331     1        1
# 110594   0.9331     1        1
#
# [19349 rows x 9 columns]

# %%
filtered_n['號誌-號誌種類名稱'].value_counts().index
# Out:
# Index(['無號誌', '行車管制號誌', '行車管制號誌(附設行人專用號誌)', '閃光號誌'], dtype='object')

# %%
import numpy as np
design = ['道路類別-第1當事者-名稱', '號誌-號誌種類名稱', '速限-第1當事者', '道路型態子類別名稱']
df = filtered_n.copy()
df['facility'] = df['facility'].astype(int)

# 對「道路組合 + facility」把 n 加總
g = (df.groupby(design + ['facility'])['n']
       .sum()
       .unstack('facility', fill_value=0)
       .rename(columns={0: 'facility_0', 1: 'facility_1'})
    )

# P(facility=1 | 道路組合)
g['total_n'] = g['facility_0'] + g['facility_1']
g['Facility_P'] = g['facility_1'] / (g['total_n']).replace(0, np.nan)

g = g.reset_index()
g = g[(g['total_n'] > 100) &
      (g['Facility_P'] > 0.1)]
g.sort_values(by='Facility_P', ascending=False, inplace=True)
g_hotspot = filter_cpd_for_hotspot(g)

# %%
for_hotspot = ['號誌-號誌種類名稱', '速限-第1當事者', '道路型態子類別名稱', 'Facility_P']
g_hotspot = g_hotspot[['號誌-號誌種類名稱', '速限-第1當事者', '道路型態子類別名稱', 'Facility_P', 'total_n']]
g_hotspot.sort_values(by=['號誌-號誌種類名稱', '速限-第1當事者', 'Facility_P'], ascending=False, inplace=True)
g_hotspot['Facility_P'] = g_hotspot['Facility_P'].round(3)
for col in ['號誌-號誌種類名稱', '道路型態子類別名稱']:
    g_hotspot[col] = g_hotspot[col].map(category_value_map[col])
g_hotspot.rename(columns=feature_name_map, inplace=True)

# %%
g_hotspot.to_excel('../ComputedData/Behaviour/BehaviourV2_hotspot.xlsx', index=False)

# %% [markdown]
# ## 去掉肇因重新分析
# 他的效果和BehaviourV2_hotspot相似，都是找出有設施的機率

# %%
parent = [
    '號誌-號誌種類名稱', '號誌-號誌動作名稱','車道劃分設施-分道設施-快車道或一般車道間名稱', '車道劃分設施-分道設施-快慢車道間名稱',
    '車道劃分設施-分道設施-路面邊線名稱', '車道劃分設施-分向設施子類別名稱', '道路型態子類別名稱',
    '速限-第1當事者', '道路類別-第1當事者-名稱', 'facility', 'COUNTYNAME'
    ]
cause = ['facility']
result = ['事故類型及型態子類別名稱']

white_list = [
    ('速限-第1當事者', 'facility'),
    ('道路類別-第1當事者-名稱', 'facility'),
    ('道路型態子類別名稱', 'facility'),
    ('號誌-號誌種類名稱', 'facility'),
]

black_list = []
# cause -> parent
black_list += [(c, p) for c in cause for p in parent]
# result -> parent/cause
black_list += [(r, x) for r in result for x in (parent + cause + result)]

# %%
def get_model(dt):
    # 學哪些變數之間有邊，結果是一個DAG
    model = bn.structure_learning.fit(dt, methodtype='hc', scoretype='bic', bw_list_method='edges',
                                    # 肇因對於事故類型一定是上游。ex. 不會因為撞路樹而造成患病，而是因為患病才造成撞路樹
                                    black_list=black_list, white_list=white_list,
                                    fixed_edges=white_list, max_indegree=None)
    # 計算每個節點的 條件機率表 (CPT, Conditional Probability Table)
    model_param = bn.parameter_learning.fit(model, dt, scoretype='bdeu', methodtype='bayes')
    # 計算邊緣強度，如果p小於顯著就是有相關
    model_independence = bn.independence_test(model_param, dt, test='chi_square', prune=True)

    return model, model_param, model_independence

model_all, model_param_all, model_independence_all = get_model(data)

# %%
from utils_behaviour import draw_bn_plotly
draw_bn_plotly(model_independence_all, layout_algo='spring', en=False, width=600, height=400, seed=42, iter=30)

# %%
from utils_behaviour import cpd_add_n, filter_cpd_for_hotspot, get_outlier
from config import category_value_map, feature_name_map
parent = ['速限-第1當事者', '道路類別-第1當事者-名稱', '道路型態子類別名稱', '號誌-號誌種類名稱']
child = 'facility'
evidence_v = list(data['facility'].value_counts().head(5).index)
CPDs = bn.print_CPD(model_param_all)
dfprob_cause = CPDs[child]
filtered = cpd_add_n(parent, child, dfprob_cause, data, threshold=0)
# Out:
# [bnlearn] >[CPD] >[Node 號誌-號誌種類名稱]:
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(無號誌)              | 0.587743  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(行車管制號誌)           | 0.261864  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(行車管制號誌(附設行人專用號誌)) | 0.099486  |
# +-----------------------------+-----------+
# | 號誌-號誌種類名稱(閃光號誌)             | 0.0509074 |
# +-----------------------------+-----------+
# [bnlearn] >[CPD] >[Node facility]:
# +---------------+-----+-------------------+
# | 號誌-號誌種類名稱     | ... | 號誌-號誌種類名稱(閃光號誌)   |
# +---------------+-----+-------------------+
# | 速限-第1當事者      | ... | 速限-第1當事者(90-99)   |
# +---------------+-----+-------------------+
# | 道路型態子類別名稱     | ... | 道路型態子類別名稱(高架道路)   |
# +---------------+-----+-------------------+
# | 道路類別-第1當事者-名稱 | ... | 道路類別-第1當事者-名稱(鄉道) |
# +---------------+-----+-------------------+
# | facility(0)   | ... | 0.5               |
# +---------------+-----+-------------------+
# | facility(1)   | ... | 0.5               |
# +---------------+-----+-------------------+
# [bnlearn] >[CPD] >[Node 道路型態子類別名稱]:
# +--------------------+-------------+
# | 道路型態子類別名稱(三岔路)     | 0.222056    |
# +--------------------+-------------+
# | 道路型態子類別名稱(休息站或服務區) | 0.000269794 |
# +--------------------+-------------+
# | 道路型態子類別名稱(其他)      | 0.00722447  |
# +--------------------+-------------+
# | 道路型態子類別名稱(四岔路)     | 0.335252    |
# +--------------------+-------------+
# | 道路型態子類別名稱(圓環)      | 0.00209051  |
# +--------------------+-------------+
# | 道路型態子類別名稱(地下道)     | 0.000986087 |
# +--------------------+-------------+
# | 道路型態子類別名稱(坡路)      | 0.0031823   |
# +--------------------+-------------+
# | 道路型態子類別名稱(多岔路)     | 0.0412153   |
# +--------------------+-------------+
# | 道路型態子類別名稱(廣場)      | 0.000266638 |
# +--------------------+-------------+
# | 道路型態子類別名稱(彎曲路及附近)  | 0.0275079   |
# +--------------------+-------------+
# | 道路型態子類別名稱(有遮斷器)    | 0.000228772 |
# +--------------------+-------------+
# | 道路型態子類別名稱(橋樑)      | 0.00487995  |
# +--------------------+-------------+
# | 道路型態子類別名稱(涵洞)      | 0.000604274 |
# +--------------------+-------------+
# | 道路型態子類別名稱(直路)      | 0.351566    |
# +--------------------+-------------+
# | 道路型態子類別名稱(隧道)      | 0.000708405 |
# +--------------------+-------------+
# | 道路型態子類別名稱(高架道路)    | 0.00196113  |
# +--------------------+-------------+
# [bnlearn] >[CPD] >[Node 速限-第1當事者]:
# +-------------------+------------+
# | 速限-第1當事者(0-9)     | 0.0123421  |
# +-------------------+------------+
# | 速限-第1當事者(10-19)   | 0.00258855 |
# +-------------------+------------+
# | 速限-第1當事者(100-109) | 0.00352257 |
# +-------------------+------------+
# | 速限-第1當事者(110-119) | 0.00379394 |
# +-------------------+------------+
# | 速限-第1當事者(20-29)   | 0.00402744 |
# +-------------------+------------+
# | 速限-第1當事者(30-39)   | 0.144112   |
# +-------------------+------------+
# | 速限-第1當事者(40-49)   | 0.13438    |
# +-------------------+------------+
# | 速限-第1當事者(50-59)   | 0.640052   |
# +-------------------+------------+
# | 速限-第1當事者(60-69)   | 0.0394477  |
# +-------------------+------------+
# | 速限-第1當事者(70-79)   | 0.0118309  |
# +-------------------+------------+
# | 速限-第1當事者(80-89)   | 0.00155039 |
# +-------------------+------------+
# | 速限-第1當事者(90-99)   | 0.00235188 |
# +-------------------+------------+
# [bnlearn] >[CPD] >[Node 道路類別-第1當事者-名稱]:
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(其他)     | 0.0330414  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(國道)     | 0.00966559 |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(專用道路)   | 0.0029097  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(市區道路)   | 0.790486   |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(快速(公)道) | 0.0012373  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(村里道路)   | 0.102594   |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(省道)     | 0.0197915  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(縣道)     | 0.0242123  |
# +-----------------------+------------+
# | 道路類別-第1當事者-名稱(鄉道)     | 0.0160617  |
# +-----------------------+------------+
# [bnlearn] >Independencies:
# (速限-第1當事者 ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱, 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | 道路型態子類別名稱)
# (速限-第1當事者 ⟂ 道路型態子類別名稱, 道路類別-第1當事者-名稱 | 號誌-號誌種類名稱)
# (速限-第1當事者 ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱 | 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ 道路類別-第1當事者-名稱 | 道路型態子類別名稱, 號誌-號誌種類名稱)
# (速限-第1當事者 ⟂ 號誌-號誌種類名稱 | 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (速限-第1當事者 ⟂ 道路型態子類別名稱 | 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 道路類別-第1當事者-名稱, 號誌-號誌種類名稱 | 速限-第1當事者)
# (道路型態子類別名稱 ⟂ 速限-第1當事者, 號誌-號誌種類名稱 | 道路類別-第1當事者-名稱)
# (道路型態子類別名稱 ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱 | 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 號誌-號誌種類名稱 | 速限-第1當事者, 道路類別-第1當事者-名稱)
# (道路型態子類別名稱 ⟂ 道路類別-第1當事者-名稱 | 速限-第1當事者, 號誌-號誌種類名稱)
# (道路型態子類別名稱 ⟂ 速限-第1當事者 | 道路類別-第1當事者-名稱, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 道路型態子類別名稱, 號誌-號誌種類名稱 | 速限-第1當事者)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者, 號誌-號誌種類名稱 | 道路型態子類別名稱)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱 | 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 號誌-號誌種類名稱 | 速限-第1當事者, 道路型態子類別名稱)
# (道路類別-第1當事者-名稱 ⟂ 道路型態子類別名稱 | 速限-第1當事者, 號誌-號誌種類名稱)
# (道路類別-第1當事者-名稱 ⟂ 速限-第1當事者 | 道路型態子類別名稱, 號誌-號誌種類名稱)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 道路型態子類別名稱, 道路類別-第1當事者-名稱 | 速限-第1當事者)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者, 道路類別-第1當事者-名稱 | 道路型態子類別名稱)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者, 道路型態子類別名稱 | 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 道路類別-第1當事者-名稱 | 速限-第1當事者, 道路型態子類別名稱)
# (號誌-號誌種類名稱 ⟂ 道路型態子類別名稱 | 速限-第1當事者, 道路類別-第1當事者-名稱)
# (號誌-號誌種類名稱 ⟂ 速限-第1當事者 | 道路型態子類別名稱, 道路類別-第1當事者-名稱)
# [bnlearn] >Nodes: ['號誌-號誌種類名稱', 'facility', '道路型態子類別名稱', '速限-第1當事者', '道路類別-第1當事者-名稱']
# [bnlearn] >Edges: [('號誌-號誌種類名稱', 'facility'), ('道路型態子類別名稱', 'facility'), ('速限-第1當事者', 'facility'), ('道路類別-第1當事者-名稱', 'facility')]

# %%
hotspot = filter_cpd_for_hotspot(filtered)
hotspot = hotspot[(hotspot['p'] > 0.1) &
                  (hotspot['n'] > 100)]

# %%
filtered_0 = hotspot[(hotspot['facility'] == '0')].sort_values(by=['p'], ascending=False)#.head(10)
filtered_1 = hotspot[(hotspot['facility'] == '1')].sort_values(by=['p'], ascending=False)#.head(10)
full_filter = pd.concat([filtered_0, filtered_1], axis=0)
full_filter.sort_values(by=['facility', '號誌-號誌種類名稱', '速限-第1當事者', 'p'], ascending=False, inplace=True)
full_filter
# for col in ['道路類別-第1當事者-名稱', '道路型態子類別名稱', '號誌-號誌種類名稱']:
#     full_filter[col] = full_filter[col].map(category_value_map[col])
# full_filter.rename(columns=feature_name_map, inplace=True)
# full_filter.to_excel(f'../ComputedData/Behaviour/Origin_outlierV2.xlsx', index=False)
# Out:
#       facility 號誌-號誌種類名稱 速限-第1當事者 道路型態子類別名稱 道路類別-第1當事者-名稱       p     n
# 13224        1      閃光號誌    50-59        直路          市區道路  0.2467   202
# 13107        1      閃光號誌    50-59       三岔路          市區道路  0.1885   539
# 13134        1      閃光號誌    50-59       四岔路          市區道路  0.1657   587
# 12963        1      閃光號誌    40-49       三岔路          市區道路  0.2326   113
# 12846        1      閃光號誌    30-39       四岔路          市區道路  0.1456   179
# ...        ...       ...      ...       ...           ...     ...   ...
# 696          0       無號誌    20-29        直路          市區道路  0.8296   195
# 264          0       無號誌    10-19        直路          市區道路  0.8185   104
# 3            0       無號誌      0-9       三岔路          市區道路  0.7619   221
# 120          0       無號誌      0-9        直路          市區道路  0.7593  1142
# 21           0       無號誌      0-9        其他          市區道路  0.6234   106
#
# [94 rows x 7 columns]

# %%
full_filter[
    (full_filter['facility'] == '0') &
    (full_filter['號誌-號誌種類名稱'] == '行車管制號誌(附設行人專用號誌)')
]
# Out:
#      facility         號誌-號誌種類名稱 速限-第1當事者 道路型態子類別名稱 道路類別-第1當事者-名稱       p     n
# 4467        0  行車管制號誌(附設行人專用號誌)    50-59       三岔路          市區道路  0.6960  3151
# 4530        0  行車管制號誌(附設行人專用號誌)    50-59       多岔路          市區道路  0.6606  1481
# 4584        0  行車管制號誌(附設行人專用號誌)    50-59        直路          市區道路  0.6488  1378
# 4494        0  行車管制號誌(附設行人專用號誌)    50-59       四岔路          市區道路  0.6330  9621
# 4386        0  行車管制號誌(附設行人專用號誌)    40-49       多岔路          市區道路  0.6979   178
# 4323        0  行車管制號誌(附設行人專用號誌)    40-49       三岔路          市區道路  0.6329   400
# 4440        0  行車管制號誌(附設行人專用號誌)    40-49        直路          市區道路  0.6312   238
# 4350        0  行車管制號誌(附設行人專用號誌)    40-49       四岔路          市區道路  0.5874   974
# 4206        0  行車管制號誌(附設行人專用號誌)    30-39       四岔路          市區道路  0.6798   344
